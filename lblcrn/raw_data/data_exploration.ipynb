# %%
# %config InlineBackend.figure_format = 'retina'  # Prevent fuzziness for retina/3K screens, comment out on other screen types.

from raw_experiment import RawExperiment
from scipy.signal import argrelextrema
import numpy as np

# %%
e = RawExperiment("data/Ir+H2O/071920 IrOx H2O")

# %%
e.show_all_samples()
# Out:
#                    Survey 735eV  Ir 4f 735 eV  O1s 735eV  VB_735eV  C1s_735eV  \
# Sample Identifier
# 0                  Survey 735eV  Ir 4f 735 eV  O1s 735eV  VB_735eV  C1s_735eV
# 1
# 2                                                                   C1s_735eV
# 3                  Survey 735eV  Ir 4f 735 eV  O1s 735eV  VB_735eV  C1s_735eV
# 4
# 5                  Survey 735eV  Ir 4f 735 eV  O1s 735eV  VB_735eV  C1s_735eV
# 6
# 7                  Survey 735eV  Ir 4f 735 eV  O1s 735eV  VB_735eV  C1s_735eV
# 8
# 9                  Survey 735eV  Ir 4f 735 eV  O1s 735eV  VB_735eV  C1s_735eV
# 10
# 11                 Survey 735eV  Ir 4f 735 eV  O1s 735eV  VB_735eV  C1s_735eV
# 12
# 13                 Survey 735eV  Ir 4f 735 eV  O1s 735eV  VB_735eV  C1s_735eV
# 14
# 15                 Survey 735eV  Ir 4f 735 eV  O1s 735eV  VB_735eV  C1s_735eV
# 16
# 17                 Survey 735eV  Ir 4f 735 eV  O1s 735eV  VB_735eV
# 18
# 19                 Survey 735eV  Ir 4f 735 eV  O1s 735eV  VB_735eV  C1s_735eV
# 20
# 21                 Survey 735eV  Ir 4f 735 eV  O1s 735eV  VB_735eV  C1s_735eV
# 22
# 23                 Survey 735eV  Ir 4f 735 eV  O1s 735eV  VB_735eV  C1s_735eV
# 24
# 25                 Survey 735eV  Ir 4f 735 eV  O1s 735eV  VB_735eV  C1s_735eV
# 26
# 27                 Survey 735eV  Ir 4f 735 eV  O1s 735eV  VB_735eV  C1s_735eV
# 28
# 29                 Survey 735eV  Ir 4f 735 eV  O1s 735eV  VB_735eV  C1s_735eV
# 30
# 31                 Survey 735eV  Ir 4f 735 eV  O1s 735eV  VB_735eV  C1s_735eV
# 32
# 33                 Survey 735eV  Ir 4f 735 eV  O1s 735eV  VB_735eV  C1s_735eV
# 34
# 35                 Survey 735eV  Ir 4f 735 eV  O1s 735eV  VB_735eV  C1s_735eV
# 36
# 37                 Survey 735eV  Ir 4f 735 eV  O1s 735eV  VB_735eV  C1s_735eV
# 38
# 39                 Survey 735eV  Ir 4f 735 eV  O1s 735eV  VB_735eV  C1s_735eV
# 40
# 41                 Survey 735eV  Ir 4f 735 eV  O1s 735eV  VB_735eV  C1s_735eV
# 42
# 43                 Survey 735eV  Ir 4f 735 eV  O1s 735eV  VB_735eV  C1s_735eV
# 44
#
#                    Ir 4f 265 eV  VB_265eV
# Sample Identifier
# 0
# 1                  Ir 4f 265 eV  VB_265eV
# 2
# 3
# 4                  Ir 4f 265 eV  VB_265eV
# 5
# 6                  Ir 4f 265 eV  VB_265eV
# 7
# 8                  Ir 4f 265 eV  VB_265eV
# 9
# 10                 Ir 4f 265 eV  VB_265eV
# 11
# 12                 Ir 4f 265 eV  VB_265eV
# 13
# 14                 Ir 4f 265 eV  VB_265eV
# 15
# 16                 Ir 4f 265 eV  VB_265eV
# 17
# 18                 Ir 4f 265 eV  VB_265eV
# 19
# 20                 Ir 4f 265 eV  VB_265eV
# 21
# 22                 Ir 4f 265 eV  VB_265eV
# 23
# 24                 Ir 4f 265 eV  VB_265eV
# 25
# 26                 Ir 4f 265 eV  VB_265eV
# 27
# 28                 Ir 4f 265 eV  VB_265eV
# 29
# 30                 Ir 4f 265 eV  VB_265eV
# 31
# 32                 Ir 4f 265 eV  VB_265eV
# 33
# 34                 Ir 4f 265 eV  VB_265eV
# 35
# 36                 Ir 4f 265 eV  VB_265eV
# 37
# 38                 Ir 4f 265 eV  VB_265eV
# 39
# 40                 Ir 4f 265 eV  VB_265eV
# 41
# 42                 Ir 4f 265 eV  VB_265eV
# 43
# 44                 Ir 4f 265 eV  VB_265eV

# %%
e[34].regions["VB_265eV"].plot()

# %%
e[34].regions["VB_265eV"].plot()

# %%
e[34].regions["VB_265eV"].produce_smoothed_version().find_steepest_section()
# Out:
# 5.200000000000015

# %%
e.calibrate("VB")
# Out:
# Region VB is not present in sample 3

# %%
# This is interesting. Should the offset be around 17?
e[1].regions["VB_265eV"].plot()

# %%
e[4].regions["VB_265eV"].plot()

# %%
e[6].regions["VB_265eV"].plot()
