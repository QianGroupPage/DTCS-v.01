# %%
import solution
import matplotlib.pyplot as plt
import substance
from mpmath import mp, mpf

# %%
s = solution.solve_ode(
    lambda t, y: [mpf(2)*t**mpf(1.5), mpf(2)*t**mpf(2), mpf(2)*t],
    [substance.Substance('x', 609), substance.Substance('y', mpf(610)), substance.Substance('z', mpf(611))],
    mpf(20), [mpf(0), mpf(1), mpf(1)])

# %%
s.sols()
# Out:
# dict_values([array([mpf('0.0'), 8.0089755113919e-11, 3.2111459130909306e-08,
#        1.0386629883992816e-05, 0.0006845391318040298,
#        0.008100321313124085, 0.027385269494861322, 0.06189784413854162,
#        0.11436312018888711, 0.1871392734264599, 0.28233594720696,
#        0.401879744306064, 0.5475550903507415, 0.7210317966864097,
#        0.9238847063049958, 1.15760828726858, 1.4236278273095697,
#        1.72330824554711, 2.0579611768916055, 2.428850769384792,
#        2.8371985000672746, 3.2841872275004778, 3.7709646404021266,
#        4.298646221401675, 4.868317816352723, 5.481037879034142,
#        6.137839445931506, 6.839731884480226, 7.587702449576194,
#        8.382717676569962, 9.225724633834702, 10.117652053966802,
#        11.059411359475089, 12.051897596246132, 13.09599028599567,
#        14.192554207222518, 15.3424401127903, 16.546485391112157,
#        17.80551467695631, 19.12034041708896, 20.491763395296378,
# ...

# %%
s.basic_plot()

# %%
s.final_state()
# Out:
# {'x': 1431.0835056706649, 'y': 5334.333333333334, 'z': 400.9999999999999}

# %%
s.var_sols('x')
# Out:
# {'x': array([0.00000000e+00, 8.00897551e-11, 3.21114591e-08, 1.03866299e-05,
#         6.84539132e-04, 8.10032131e-03, 2.73852695e-02, 6.18978441e-02,
#         1.14363120e-01, 1.87139273e-01, 2.82335947e-01, 4.01879744e-01,
#         5.47555090e-01, 7.21031797e-01, 9.23884706e-01, 1.15760829e+00,
#         1.42362783e+00, 1.72330825e+00, 2.05796118e+00, 2.42885077e+00,
#         2.83719850e+00, 3.28418723e+00, 3.77096464e+00, 4.29864622e+00,
#         4.86831782e+00, 5.48103788e+00, 6.13783945e+00, 6.83973188e+00,
#         7.58770245e+00, 8.38271768e+00, 9.22572463e+00, 1.01176521e+01,
#         1.10594114e+01, 1.20518976e+01, 1.30959903e+01, 1.41925542e+01,
#         1.53424401e+01, 1.65464854e+01, 1.78055147e+01, 1.91203404e+01,
#         2.04917634e+01, 2.19205732e+01, 2.34075488e+01, 2.49534587e+01,
#         2.65590616e+01, 2.82251067e+01, 2.99523341e+01, 3.17414748e+01,
#         3.35932515e+01, 3.55083785e+01, 3.74875624e+01, 3.95315017e+01,
# ...

# %%
s.plot_gaussian(show_sum=True)
